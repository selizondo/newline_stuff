# %% [markdown]
# #### set python paths

# %%
import os
import sys

newline_root = "/Users/selizondo/Dropbox/external_repos/newline"

newline_diy_repair = os.path.join(newline_root, "mini-project/synethtic-data-Home-DIY-Repair")
newline_project_a = os.path.join(newline_root, "projects/mini-project-1/solution")

sys.path.insert(0, newline_root)
sys.path.insert(0, newline_diy_repair)
sys.path.insert(0, newline_project_a)

# %%
#from generation_phase import *
from phase1_generation import *

# %%
model= "gpt-3.5-turbo"
num_samples = 1
generator = DIYRepairGenerator(model=model)
results = generator.generate_batch(num_samples)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 model= "gpt-3.5-turbo"
#       2 num_samples = 1
# ----> 3 generator = DIYRepairGenerator(model=model)
#       4 results = generator.generate_batch(num_samples)
#
# File ~/Dropbox/external_repos/newline/projects/mini-project-1/solution/phase1_generation.py:22, in DIYRepairGenerator.__init__(self, model, use_corrected)
#      20 self.model = model
#      21 self.templates = CORRECTED_TEMPLATES if use_corrected else BASELINE_TEMPLATES
# ---> 22 self.settings = get_settings()
#
# File ~/Dropbox/external_repos/newline/projects/mini-project-1/solution/config.py:28, in get_settings()
#      25 model = os.getenv("LLM_MODEL", "gpt-4o-mini")
#      27 if not api_key:
# ---> 28     raise ValueError(
#      29         "LLM_API_KEY is not set. Copy .env.example to .env and fill in your credentials."
# ...

# %%
results

# %%
from datasets import load_dataset

dataset = load_dataset("dipenbhuva/home-diy-repair-qa")

train = dataset["train"]
eval_set = dataset["eval"]

print(train[0])

# %%
print(train[1])

# %%
print(train[2])
